# %%
#Importing packages
import json
from lxml import html
from selenium import webdriver
import pandas as pd
import requests
import splinter
from splinter import Browser

# %%
driver = webdriver.Chrome('c:/Users/chromedriver.exe')

# %%
Date = '02/05/2020'
Depart_apt = 'ORD'
Arriv_apt = 'LAX'

# %%
driver.get('https://www.expedia.com/Flights-Search?trip=oneway&leg1=from:' + Depart_apt +',to:' + Arriv_apt + ',departure:' + Date + 'TANYT&passengers=adults:1,children:0,seniors:0,infantinlap:Y&options=cabinclass%3Aeconomy&mode=search&origref=www.expedia.com')

# %%
results_element = driver.find_elements_by_xpath('/html/body/div[2]/div[8]/section/div/div[10]/ul')[0]
#userid_element = driver.find_elements_by_xpath('//script[@id='cachedResultsJson']//text()'
results = results_element.text
results.split('\n')
# Out:
# ['Result 1 when sorted by price, $98',
#  '10:17pm',
#  '- 12:52am +1',
#  'Flight spans 1 day',
#  'American Airlines',
#  'Very Good Flights (8.4/10)',
#  '4h 35m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 1, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 1',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 1, collapsed.',
#  'Result 2 when sorted by price, $98',
#  '5:00pm',
#  '- 7:37pm',
#  'American Airlines',
#  'Very Good Flights (8.4/10)',
#  '4h 37m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 2, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 2',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 2, collapsed.',
#  'Result 3 when sorted by price, $98',
#  '8:29pm',
#  '- 11:07pm',
#  'American Airlines',
#  'Very Good Flights (8.4/10)',
#  '4h 38m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 3, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 3',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 3, collapsed.',
#  'Result 4 when sorted by price, $98',
#  '7:35am',
#  '- 10:14am',
#  'American Airlines',
#  'Very Good Flights (8.4/10)',
#  '4h 39m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 4, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 4',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 4, collapsed.',
#  'Result 5 when sorted by price, $98',
#  '6:37pm',
#  '- 9:22pm',
#  'American Airlines',
#  'Excellent Flights (8.5/10)',
#  '4h 45m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 5, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 5',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 5, collapsed.',
#  'Result 6 when sorted by price, $98',
#  '5:40pm',
#  '- 8:32pm',
#  'Alaska Airlines',
#  'Very Good Flights (8.3/10)',
#  '4h 52m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$98',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 6 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 6',
#  'Rules and restrictions apply',
#  'Result 6.',
#  'Result 7 when sorted by price, $99',
#  '8:20am',
#  '- 10:54am',
#  'United',
#  'Very Good Flights (8.2/10)',
#  '4h 34m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 7, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 7',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 7, collapsed.',
#  'Result 8 when sorted by price, $99',
#  '3:53pm',
#  '- 6:30pm',
#  'United',
#  'Very Good Flights (8.2/10)',
#  '4h 37m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 8, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 8',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 8, collapsed.',
#  'Result 9 when sorted by price, $99',
#  '7:59pm',
#  '- 10:36pm',
#  'United',
#  'Very Good Flights (8.2/10)',
#  '4h 37m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 9, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 9',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 9, collapsed.',
#  'Result 10 when sorted by price, $99',
#  '10:18am',
#  '- 12:56pm',
#  'United',
#  'Very Good Flights (7.9/10)',
#  '4h 38m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi and Entertainment information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 10, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 10',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 10, collapsed.',
#  'Result 11 when sorted by price, $99',
#  '12:50pm',
#  '- 3:30pm',
#  'United',
#  'Very Good Flights (8.2/10)',
#  '4h 40m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 11, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 11',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 11, collapsed.',
#  'Result 12 when sorted by price, $99',
#  '11:41am',
#  '- 2:22pm',
#  'United',
#  'Very Good Flights (8.2/10)',
#  '4h 41m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 12, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 12',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 12, collapsed.',
#  'Result 13 when sorted by price, $99',
#  '5:50pm',
#  '- 8:31pm',
#  'United',
#  'Very Good Flights (7.9/10)',
#  '4h 41m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi and Entertainment information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$99',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 13, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 13',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 13, collapsed.',
#  'Result 14 when sorted by price, $107',
#  '10:55am',
#  '- 3:25pm',
#  'American Airlines',
#  'Good Flights (7/10)',
#  '6h 30m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 57m in PHX',
#  'Layover 57m in PHX',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 14, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 14',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 14, collapsed.',
#  'Result 15 when sorted by price, $107',
#  '6:00am',
#  '- 10:55am',
#  'American Airlines',
#  'Satisfactory Flights (6.7/10)',
#  '6h 55m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 18m in PHX',
#  'Layover 1h 18m in PHX',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 15, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 15',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 15, collapsed.',
#  'Result 16 when sorted by price, $107',
#  '5:10pm',
#  '- 10:10pm',
#  'American Airlines',
#  'Satisfactory Flights (6.7/10)',
#  '7h 0m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 44m in SJC',
#  'Layover 44m in SJC',
#  'Arrival airport:',
#  '- LAX',
#  'American Airlines 6059 operated by Compass Airlines As American Eagle',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 16, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 16',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 16, collapsed.',
#  'Result 17 when sorted by price, $107',
#  '3:09pm',
#  '- 8:22pm',
#  'American Airlines',
#  'Satisfactory Flights (6.6/10)',
#  '7h 13m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 38m in STL',
#  'Layover 1h 38m in STL',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 17, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 17',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 17, collapsed.',
#  'Result 18 when sorted by price, $107',
#  '11:50am',
#  '- 5:19pm',
#  'American Airlines',
#  'Satisfactory Flights (6.3/10)',
#  '7h 29m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 59m in OMA',
#  'Layover 1h 59m in OMA',
#  'Arrival airport:',
#  '- LAX',
#  'American Airlines 3074 operated by Skywest Airlines As American Eagle, American Airlines 6008 operated by Compass Airlines As American Eagle',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 18, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 18',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 18, collapsed.',
#  'Result 19 when sorted by price, $107',
#  '9:44am',
#  '- 3:25pm',
#  'American Airlines',
#  'Satisfactory Flights (6.1/10)',
#  '7h 41m (1 stop)',
#  'Available amenities',
#  'Wi-Fi and Entertainment information',
#  'Departure airport:',
#  'ORD - 2h 5m in PHX',
#  'Layover 2h 5m in PHX',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 19, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 19',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 19, collapsed.',
#  'Result 20 when sorted by price, $107',
#  '1:58pm',
#  '- 8:22pm',
#  'American Airlines',
#  'Satisfactory Flights (6/10)',
#  '8h 24m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 2h 46m in STL',
#  'Layover 2h 46m in STL',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 20, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 20',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 20, collapsed.',
#  'Result 21 when sorted by price, $107',
#  '8:20am',
#  '- 3:25pm',
#  'American Airlines',
#  'Fair Flights (5.5/10)',
#  '9h 5m (1 stop)',
#  'Available amenities',
#  'Wi-Fi and Entertainment information',
#  'Departure airport:',
#  'ORD - 3h 33m in PHX',
#  'Layover 3h 33m in PHX',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 21, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 21',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 21, collapsed.',
#  'Result 22 when sorted by price, $107',
#  '9:44am',
#  '- 4:50pm',
#  'American Airlines',
#  'Fair Flights (5.4/10)',
#  '9h 6m (1 stop)',
#  'Available amenities',
#  'Wi-Fi and Entertainment information',
#  'Departure airport:',
#  'ORD - 3h 33m in PHX',
#  'Layover 3h 33m in PHX',
#  'Arrival airport:',
#  '- LAX',
#  '$107',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'View fare options and select flight for result 22, collapsed.',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 22',
#  'Fare options (restrictions apply)',
#  'View fare options and select flight for result 22, collapsed.',
#  'Result 23 when sorted by price, $109',
#  '8:30am',
#  '- 11:11am',
#  'American Airlines',
#  'Excellent Flights (8.5/10)',
#  '4h 41m (Nonstop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '$109',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 23 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 23',
#  'Rules and restrictions apply',
#  'Result 23.',
#  'Result 24 when sorted by price, $122',
#  '9:30am',
#  '- 12:15pm',
#  'Spirit Airlines',
#  'Good Flights (7/10)',
#  '4h 45m (Nonstop)',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '4 left at $122',
#  'one way',
#  'Select',
#  'Select result 24 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 24',
#  'Rules and restrictions apply',
#  'Result 24.',
#  'Result 25 when sorted by price, $122',
#  '3:15pm',
#  '- 6:00pm',
#  'Spirit Airlines',
#  'Good Flights (7/10)',
#  '4h 45m (Nonstop)',
#  'Departure airport:',
#  'ORD -',
#  'Arrival airport:',
#  'LAX',
#  '4 left at $122',
#  'one way',
#  'Select',
#  'Select result 25 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 25',
#  'Rules and restrictions apply',
#  'Result 25.',
#  'Result 26 when sorted by price, $123',
#  '12:15pm',
#  '- 4:35pm',
#  'Delta',
#  'Good Flights (7.2/10)',
#  '6h 20m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 43m in MSP',
#  'Layover 43m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 26 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 26',
#  'Rules and restrictions apply',
#  'Result 26.',
#  'Result 27 when sorted by price, $123',
#  '10:44am',
#  '- 3:07pm',
#  'Delta',
#  'Good Flights (7.1/10)',
#  '6h 23m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 44m in MSP',
#  'Layover 44m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 27 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 27',
#  'Rules and restrictions apply',
#  'Result 27.',
#  'Result 28 when sorted by price, $123',
#  '3:25pm',
#  '- 7:56pm',
#  'Delta',
#  'Good Flights (7.1/10)',
#  '6h 31m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 42m in MSP',
#  'Layover 42m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 28 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 28',
#  'Rules and restrictions apply',
#  'Result 28.',
#  'Result 29 when sorted by price, $123',
#  '7:27am',
#  '- 12:08pm',
#  'Delta',
#  'Good Flights (7/10)',
#  '6h 41m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 50m in SLC',
#  'Layover 50m in SLC',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 29 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 29',
#  'Rules and restrictions apply',
#  'Result 29.',
#  'Result 30 when sorted by price, $123',
#  '6:10am',
#  '- 10:55am',
#  'Delta',
#  'Good Flights (7/10)',
#  '6h 45m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 53m in MSP',
#  'Layover 53m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 30 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 30',
#  'Rules and restrictions apply',
#  'Result 30.',
#  'Result 31 when sorted by price, $123',
#  '6:00am',
#  '- 10:50am',
#  'Delta',
#  'Satisfactory Flights (6.9/10)',
#  '6h 50m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 53m in SLC',
#  'Layover 53m in SLC',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 31 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 31',
#  'Rules and restrictions apply',
#  'Result 31.',
#  'Result 32 when sorted by price, $123',
#  '12:48pm',
#  '- 5:57pm',
#  'Delta',
#  'Satisfactory Flights (6.7/10)',
#  '7h 9m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 30m in DTW',
#  'Layover 30m in DTW',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 32 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 32',
#  'Rules and restrictions apply',
#  'Result 32.',
#  'Result 33 when sorted by price, $123',
#  '10:44am',
#  '- 4:35pm',
#  'Delta',
#  'Satisfactory Flights (6.4/10)',
#  '7h 51m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 2h 17m in MSP',
#  'Layover 2h 17m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 33 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 33',
#  'Rules and restrictions apply',
#  'Result 33.',
#  'Result 34 when sorted by price, $123',
#  '9:08am',
#  '- 3:07pm',
#  'Delta',
#  'Satisfactory Flights (6.3/10)',
#  '7h 59m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 2h 14m in MSP',
#  'Layover 2h 14m in MSP',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 34 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 34',
#  'Rules and restrictions apply',
#  'Result 34.',
#  'Result 35 when sorted by price, $123',
#  '8:17am',
#  '- 2:20pm',
#  'Delta',
#  'Satisfactory Flights (6.3/10)',
#  '8h 3m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 2m in ATL',
#  'Layover 1h 2m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 35 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 35',
#  'Rules and restrictions apply',
#  'Result 35.',
#  'Result 36 when sorted by price, $123',
#  '6:00am',
#  '- 12:08pm',
#  'Delta',
#  'Satisfactory Flights (6.2/10)',
#  '8h 8m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 2h 13m in SLC',
#  'Layover 2h 13m in SLC',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 36 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 36',
#  'Rules and restrictions apply',
#  'Result 36.',
#  'Result 37 when sorted by price, $123',
#  '7:10am',
#  '- 1:20pm',
#  'Delta',
#  'Satisfactory Flights (6.2/10)',
#  '8h 10m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h in ATL',
#  'Layover 1h in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 37 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 37',
#  'Rules and restrictions apply',
#  'Result 37.',
#  'Result 38 when sorted by price, $123',
#  '9:20am',
#  '- 3:41pm',
#  'Delta',
#  'Satisfactory Flights (6/10)',
#  '8h 21m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 17m in ATL',
#  'Layover 1h 17m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 38 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 38',
#  'Rules and restrictions apply',
#  'Result 38.',
#  'Result 39 when sorted by price, $123',
#  '12:04pm',
#  '- 6:28pm',
#  'Delta',
#  'Satisfactory Flights (6/10)',
#  '8h 24m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 23m in ATL',
#  'Layover 1h 23m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 39 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 39',
#  'Rules and restrictions apply',
#  'Result 39.',
#  'Result 40 when sorted by price, $123',
#  '2:00pm',
#  '- 8:24pm',
#  'Delta',
#  'Satisfactory Flights (6.1/10)',
#  '8h 24m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h in SEA',
#  'Layover 1h in SEA',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 40 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 40',
#  'Rules and restrictions apply',
#  'Result 40.',
#  'Result 41 when sorted by price, $123',
#  '5:30am',
#  '- 11:55am',
#  'Delta',
#  'Satisfactory Flights (6.1/10)',
#  '8h 25m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 22m in ATL',
#  'Layover 1h 22m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 41 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 41',
#  'Rules and restrictions apply',
#  'Result 41.',
#  'Result 42 when sorted by price, $123',
#  '1:10pm',
#  '- 7:52pm',
#  'Delta',
#  'Fair Flights (5.8/10)',
#  '8h 42m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 48m in ATL',
#  'Layover 1h 48m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 42 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 42',
#  'Rules and restrictions apply',
#  'Result 42.',
#  'Result 43 when sorted by price, $123',
#  '11:14am',
#  '- 5:57pm',
#  'Delta',
#  'Fair Flights (5.8/10)',
#  '8h 43m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 2h 3m in DTW',
#  'Layover 2h 3m in DTW',
#  'Arrival airport:',
#  '- LAX',
#  'Delta 4920 operated by Endeavor Air DBA Delta Connection',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 43 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 43',
#  'Rules and restrictions apply',
#  'Result 43.',
#  'Result 44 when sorted by price, $123',
#  '10:28am',
#  '- 5:18pm',
#  'Delta',
#  'Fair Flights (5.9/10)',
#  '8h 50m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  'Departure airport:',
#  'ORD - 1h 47m in ATL',
#  'Layover 1h 47m in ATL',
#  'Arrival airport:',
#  '- LAX',
#  '$123',
#  'one way',
#  'Free cancel within 24 hrs',
#  'Free Cancel w/in 24 hrs',
#  'Select',
#  'Select result 44 when sorted by price',
#  'Details & baggage fees ',
#  'Details and baggage fees for result 44',
#  'Rules and restrictions apply',
#  'Result 44.',
#  'Result 45 when sorted by price, $123',
#  '7:10am',
#  '- 2:20pm',
#  'Delta',
#  'Fair Flights (5.7/10)',
#  '9h 10m (1 stop)',
#  'Available amenities',
#  'Wi-Fi, Entertainment, and Power information',
#  ...]

# %%
for i in range(1):
    x = '/html/body/div[2]/div[8]/section/div/div[10]/ul'
    
    result_id_element = driver.find_elements_by_xpath(x + '/li[2]/h3')[0]
    result_id = result_id_element.text
    
    x0 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[2]/div[1]/div[1]'
    x1 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[3]/div[1]/div[1]'
    x2 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[4]/div[1]/div[1]'
    x3 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[5]/div[1]/div[1]'
    x4 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[6]/div[1]/div[1]'
    
    airline_id_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[1]/div[2]/span')[0]
    airline_id = airline_id_element.text
    
    depart_time_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[1]/div[1]/span/span[1]')[0]
    depart_time = depart_time_element.text
    
    arriv_time_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[1]/div[1]/span/span[4]')[0]
    arriv_time = arriv_time_element.text
    
    duration_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[2]/div[1]/span[1]')[0]
    duration = duration_element.text
    
    no_stops_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[2]/div[1]/span[2]')[0]
    no_stops = no_stops_element.text
    
    depart_arrival_apt_element = driver.find_elements_by_xpath(x0 + '/div[1]/div/div/div/div[2]/div[2]')[0]
    depart_arrival_apt = depart_arrival_apt_element.text
    
    price_element = driver.find_elements_by_xpath(x0 + '/div[2]/div/div[1]/div[1]/span')[0]
    price = price_element.text

    print(Date, Depart_apt, Arriv_apt, airline_id, depart_time, arriv_time, duration, no_stops, price)
# Out:
# 02/05/2020 ORD LAX American Airlines 5:00pm 7:37pm 4h 37m (Nonstop) $98

# %%
result_id_element = driver.find_elements_by_xpath(x + '/li[2]/h3')[0]
result_id = result_id_element.text
result_id

# %%
x1 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[2]/div[1]/div[1]'
x2 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[3]/div[1]/div[1]'
x3 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[4]/div[1]/div[1]'
x4 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[5]/div[1]/div[1]'
x5 = '/html/body/div[2]/div[8]/section/div/div[10]/ul/li[6]/div[1]/div[1]'

# %%
airline_id_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[1]/div[2]/span')[0]
airline_id = airline_id_element.text
airline_id

# %%
depart_time_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[1]/div[1]/span/span[1]')[0]
depart_time = depart_time_element.text
depart_time

# %%
arriv_time_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[1]/div[1]/span/span[4]')[0]
arriv_time = arriv_time_element.text
arriv_time

# %%
duration_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[2]/div[1]/span[1]')[0]
duration = duration_element.text
duration

# %%
no_stops_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[2]/div[1]/span[2]')[0]
no_stops = no_stops_element.text
no_stops

# %%
depart_arrival_apt_element = driver.find_elements_by_xpath(x1 + '/div[1]/div/div/div/div[2]/div[2]')[0]
depart_arrival_apt = depart_arrival_apt_element.text
depart_arrival_apt

# %%
price_element = driver.find_elements_by_xpath(x1 + '/div[2]/div/div[1]/div[1]/span')[0]

price = price_element.text
price

# %%
flights = pd.DataFrame(columns = ['Date','Airline','Depart_time', 'Arr_time', 'No_stops', 'Depart_apt', 'Arr_apt', 'Price']) 

ids = driver.find_elements_by_xpath('/html/body/div[2]/div[8]/section/div/div[10]/ul')[0]
flight_ids = []
for i in ids:
    flight_ids.append(i.get_attribute('id'))

for x in flight_ids:
    #Extract dates from for each user on a page
    user_date = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[2]/span[1]/a/time')[0]
    date = user_date.get_attribute('title')

    #Extract user ids from each user on a page
    userid_element = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[1]/span[1]/a[2]')[0]
    userid = userid_element.text

    #Extract Message for each user on a page
    user_message = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[3]/div/div[1]')[0]
    comment = user_message.text
                                   
    #Adding date, userid and comment for each user in a dataframe    
    comments.loc[len(comments)] = [date,userid,comment]
