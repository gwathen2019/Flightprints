# %%
#import modules
import os
import csv
import pandas as pd
import numpy as np

# %%
# Make a reference to the flights_data.csv file path
csv_path = "data/887990933_T_DB1B_MARKET.csv"

# Import the flights_data.csv file as a DataFrame
flights2019_df = pd.read_csv(csv_path, encoding="utf-8")
flights2019_df.head()
# Out:
#    YEAR  QUARTER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_COUNTRY  ORIGIN_STATE_FIPS  \
# 0  2019        1              11278    DCA             US                 51
# 1  2019        1              11278    DCA             US                 51
# 2  2019        1              11278    DCA             US                 51
# 3  2019        1              11278    DCA             US                 51
# 4  2019        1              11278    DCA             US                 51
#
#   ORIGIN_STATE_ABR  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST DEST_COUNTRY  \
# 0               VA            11481              1148102  ECP           US
# 1               VA            11481              1148102  ECP           US
# 2               VA            11481              1148102  ECP           US
# 3               VA            11481              1148102  ECP           US
# 4               VA            11481              1148102  ECP           US
#
# ...

# %%
# Make a reference to the flights_data.csv file path
csv_airport_path = "data/L_AIRPORT.csv"

# Import the flights_data.csv file as a DataFrame
airports_df = pd.read_csv(csv_airport_path, encoding="utf-8")
airports_df.head()
# Out:
#   Code                                    Description
# 0  01A         Afognak Lake, AK: Afognak Lake Airport
# 1  03A  Granite Mountain, AK: Bear Creek Mining Strip
# 2  04A                       Lik, AK: Lik Mining Camp
# 3  05A         Little Squaw, AK: Little Squaw Airport
# 4  06A                     Kizhuyak, AK: Kizhuyak Bay

# %%
Origin = airports_df["Code"]
Origin_desc = airports_df["Description"]
Destination = airports_df["Code"]
Dest_desc = airports_df["Description"]

# %%
#create a new table airport data
origin_airport_table = pd.DataFrame({"Origin": Origin,
                          "Origin_desc": Origin_desc})

origin_airport_table.info()
origin_airport_table.head(50)
#new_table.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6554 entries, 0 to 6553
# Data columns (total 2 columns):
# Origin         6554 non-null object
# Origin_desc    6554 non-null object
# dtypes: object(2)
# memory usage: 102.5+ KB
#    Origin                                       Origin_desc
# 0     01A            Afognak Lake, AK: Afognak Lake Airport
# 1     03A     Granite Mountain, AK: Bear Creek Mining Strip
# 2     04A                          Lik, AK: Lik Mining Camp
# 3     05A            Little Squaw, AK: Little Squaw Airport
# 4     06A                        Kizhuyak, AK: Kizhuyak Bay
# 5     07A                Klawock, AK: Klawock Seaplane Base
# 6     08A    Elizabeth Island, AK: Elizabeth Island Airport
# 7     09A                        Homer, AK: Augustin Island
# 8     1B1                       Hudson, NY: Columbia County
# 9     1CA                Rio Vista, CA: Rio Vista Municipal
# 10    1G4              Peach Springs, AZ: Grand Canyon West
# ...

# %%
#create a new table airport data
dest_airport_table = pd.DataFrame({"Destination": Destination,
                          "Dest_desc": Dest_desc})

dest_airport_table.info()
dest_airport_table.head(50)
#new_table.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6554 entries, 0 to 6553
# Data columns (total 2 columns):
# Destination    6554 non-null object
# Dest_desc      6554 non-null object
# dtypes: object(2)
# memory usage: 102.5+ KB
#    Destination                                         Dest_desc
# 0          01A            Afognak Lake, AK: Afognak Lake Airport
# 1          03A     Granite Mountain, AK: Bear Creek Mining Strip
# 2          04A                          Lik, AK: Lik Mining Camp
# 3          05A            Little Squaw, AK: Little Squaw Airport
# 4          06A                        Kizhuyak, AK: Kizhuyak Bay
# 5          07A                Klawock, AK: Klawock Seaplane Base
# 6          08A    Elizabeth Island, AK: Elizabeth Island Airport
# 7          09A                        Homer, AK: Augustin Island
# 8          1B1                       Hudson, NY: Columbia County
# 9          1CA                Rio Vista, CA: Rio Vista Municipal
# ...

# %%
flights2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508753 entries, 0 to 6508752
# Data columns (total 19 columns):
# YEAR                   int64
# QUARTER                int64
# ORIGIN_AIRPORT_ID      int64
# ORIGIN                 object
# ORIGIN_COUNTRY         object
# ORIGIN_STATE_FIPS      int64
# ORIGIN_STATE_ABR       object
# DEST_AIRPORT_ID        int64
# DEST_AIRPORT_SEQ_ID    int64
# DEST                   object
# DEST_COUNTRY           object
# DEST_STATE_FIPS        int64
# DEST_STATE_ABR         object
# PASSENGERS             float64
# MARKET_FARE            float64
# MARKET_DISTANCE        float64
# DISTANCE_GROUP         int64
# MARKET_MILES_FLOWN     float64
# Unnamed: 18            float64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 943.5+ MB

# %%
origin_cnt = flights2019_df["ORIGIN"].value_counts()
#origin_cnt

# %%
dest_cnt = flights2019_df["DEST"].value_counts()
#dest_cnt

# %%
orig_dest = flights2019_df["ORIGIN"] + "-" + flights2019_df["DEST"]
year = flights2019_df["YEAR"]
Origin = flights2019_df["ORIGIN"]
Destination = flights2019_df["DEST"]
Origin_cntry =  flights2019_df["ORIGIN_COUNTRY"]
Origin_state_FIPS = flights2019_df["ORIGIN_STATE_FIPS"]
Origin_state = flights2019_df["ORIGIN_STATE_ABR"]
Dest_cntry = flights2019_df["DEST_COUNTRY"]
Dest_state_FIPS = flights2019_df["DEST_STATE_FIPS"]
Dest_state = flights2019_df["DEST_STATE_ABR"]
Passengers = flights2019_df["PASSENGERS"]
Market_fare = flights2019_df["MARKET_FARE"]
Market_dist = flights2019_df["MARKET_DISTANCE"]
Distance_grp = flights2019_df["DISTANCE_GROUP"]
Market_miles_flown = flights2019_df["MARKET_MILES_FLOWN"]
#orig_dest

# %%
#create a new table with orig_dest variable included
new_table = pd.DataFrame({"Year": year,
                          "Origin": Origin,
                          "Destination": Destination,
                          "Origin_Dest": orig_dest,
                          "Origin_cntry": Origin_cntry,
                          "Origin_state_FIPS": Origin_state_FIPS,
                          "Origin_state": Origin_state,
                          "Dest_cntry": Dest_cntry,
                          "Dest_state_FIPS": Dest_state_FIPS,
                          "Dest_state": Dest_state,
                          "Passengers": Passengers,
                          "Market_fare": Market_fare,
                          "Market_dist": Market_dist,
                          "Distance_grp": Distance_grp,
                          "Market_miles_flown": Market_miles_flown})

new_table.info()
new_table.head(50)
#new_table.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6574395 entries, 0 to YUM-YKM
# Data columns (total 15 columns):
# Year                  float64
# Origin                object
# Destination           object
# Origin_Dest           object
# Origin_cntry          object
# Origin_state_FIPS     float64
# Origin_state          object
# Dest_cntry            object
# Dest_state_FIPS       float64
# Dest_state            object
# Passengers            float64
# Market_fare           float64
# Market_dist           float64
# Distance_grp          float64
# Market_miles_flown    float64
# dtypes: float64(8), object(7)
# memory usage: 802.5+ MB
#       Year Origin Destination Origin_Dest Origin_cntry  Origin_state_FIPS  \
# 0   2019.0    DCA         ECP     DCA-ECP           US               51.0
# 1   2019.0    DCA         ECP     DCA-ECP           US               51.0
# 2   2019.0    DCA         ECP     DCA-ECP           US               51.0
# ...

# %%
# Merge two dataframes using an inner join
merge_flight_table = pd.merge(new_table, origin_airport_table, on="Origin")

merge_flight_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6508753 entries, 0 to 6508752
# Data columns (total 16 columns):
# Year                  float64
# Origin                object
# Destination           object
# Origin_Dest           object
# Origin_cntry          object
# Origin_state_FIPS     float64
# Origin_state          object
# Dest_cntry            object
# Dest_state_FIPS       float64
# Dest_state            object
# Passengers            float64
# Market_fare           float64
# Market_dist           float64
# Distance_grp          float64
# Market_miles_flown    float64
# Origin_desc           object
# dtypes: float64(8), object(8)
# memory usage: 844.2+ MB

# %%
# Merge two dataframes using an inner join
merge2_flight_table = pd.merge(merge_flight_table, dest_airport_table, on="Destination")

merge2_flight_table.info()
merge2_flight_table.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6508753 entries, 0 to 6508752
# Data columns (total 17 columns):
# Year                  float64
# Origin                object
# Destination           object
# Origin_Dest           object
# Origin_cntry          object
# Origin_state_FIPS     float64
# Origin_state          object
# Dest_cntry            object
# Dest_state_FIPS       float64
# Dest_state            object
# Passengers            float64
# Market_fare           float64
# Market_dist           float64
# Distance_grp          float64
# Market_miles_flown    float64
# Origin_desc           object
# Dest_desc             object
# dtypes: float64(8), object(9)
# memory usage: 893.8+ MB
#      Year Origin Destination Origin_Dest Origin_cntry  Origin_state_FIPS  \
# 0  2019.0    DCA         ECP     DCA-ECP           US               51.0
# 1  2019.0    DCA         ECP     DCA-ECP           US               51.0
# ...

# %%
origdest_cnt = merge2_flight_table["Origin_Dest"].value_counts()
origin_apt = merge2_flight_table["Origin"]
dest_apt = merge2_flight_table["Destination"]
passenger_sum = merge2_flight_table["Passengers"].sum()


print(passenger_sum)
# Out:
# 0.0

# %%
origdest_count = len(merge2_flight_table["Origin_Dest"].unique())
origdest_count
# Out:
# 65642

# %%
route_table = merge2_flight_table.groupby(["Origin_Dest"])
Origin_airport = route_table["Origin"]
Origin_airport_name = route_table["Origin_desc"]
Passengers = route_table["Passengers"].sum()

# %%
route_summary_table = pd.DataFrame({"Route": Origin_Dest,
                                   "Origin Airport": Origin,
                                   "Origin Airport Name": Origin_desc,
                                   "Passengers": Passengers})
route_summary_table.info()
route_summary_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-62f82f8dbda2> in <module>
# ----> 1 route_summary_table = pd.DataFrame({"Route": Origin_Dest,
#       2                                    "Origin Airport": Origin,
#       3                                    "Origin Airport Name": Origin_desc,
#       4                                    "Passengers": Passengers})
#       5 route_summary_table.info()
#
# NameError: name 'Origin_Dest' is not defined
